# %%
import json

geojson = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {
                "Stadium": "State Farm Stadium",
                "City": "Glendale, Arizona",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-112.2625, 33.5275]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Allegiant Stadium",
                "City": "Las Vegas, Nevada",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-115.1831, 36.0908]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "AT&T Stadium",
                "City": "Arlington, Texas",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-97.0945, 32.7473]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Raymond James Stadium",
                "City": "Tampa, Florida",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-82.5033, 27.9759]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "NRG Stadium",
                "City": "Houston, Texas",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-95.4107, 29.6847]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Mercedes-Benz Stadium",
                "City": "Atlanta, Georgia",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-84.4008, 33.7554]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Nissan Stadium",
                "City": "Nashville, Tennessee",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-86.7713, 36.1664]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Lincoln Financial Field",
                "City": "Philadelphia, Pennsylvania",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-75.1675, 39.9008]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Gillette Stadium",
                "City": "Foxborough, Massachusetts",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-71.2643, 42.0909]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "MetLife Stadium",
                "City": "East Rutherford, New Jersey",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-74.0744, 40.8135]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Soldier Field",
                "City": "Chicago, Illinois",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-87.6167, 41.8623]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Ford Field",
                "City": "Detroit, Michigan",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-83.0456, 42.3391]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Acrisure Stadium",
                "City": "Pittsburgh, Pennsylvania",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-80.0158, 40.4468]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "U.S. Bank Stadium",
                "City": "Minneapolis, Minnesota",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-93.2573, 44.9737]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Paycor Stadium",
                "City": "Cincinnati, Ohio",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-84.5161, 39.0955]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Arrowhead Stadium",
                "City": "Kansas City, Missouri",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-94.4839, 39.0490]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Empower Field at Mile High",
                "City": "Denver, Colorado",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-105.0201, 39.7439]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Lumen Field",
                "City": "Seattle, Washington",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-122.3316, 47.5952]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Levi's Stadium",
                "City": "Santa Clara, California",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-121.9702, 37.4035]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "SoFi Stadium",
                "City": "Inglewood, California",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-118.3392, 33.9535]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Hard Rock Stadium",
                "City": "Miami, Florida",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-80.2389, 25.9580]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Caesars Superdome",
                "City": "New Orleans, Louisiana",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-90.0812, 29.9511]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Lucas Oil Stadium",
                "City": "Indianapolis, Indiana",
                "Country": "USA"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-86.1639, 39.7601]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Foro Sol",
                "City": "Mexico City",
                "Country": "Mexico"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-99.0907, 19.4042]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Estadio River Plate",
                "City": "Buenos Aires",
                "Country": "Argentina"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-58.4497, -34.5456]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Estádio Nilton Santos",
                "City": "Rio de Janeiro",
                "Country": "Brazil"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-43.2302, -22.9122]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Allianz Parque",
                "City": "São Paulo",
                "Country": "Brazil"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-46.6786, -23.5275]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Tokyo Dome",
                "City": "Tokyo",
                "Country": "Japan"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [139.7514, 35.7055]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Melbourne Cricket Ground",
                "City": "Melbourne",
                "Country": "Australia"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [144.9834, -37.8199]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Accor Stadium",
                "City": "Sydney",
                "Country": "Australia"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [151.0634, -33.8474]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "National Stadium",
                "City": "Singapore",
                "Country": "Singapore"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [103.8746, 1.3055]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Stade de France",
                "City": "Paris",
                "Country": "France"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [2.3602, 48.9245]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Friends Arena",
                "City": "Stockholm",
                "Country": "Sweden"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [18.0056, 59.3729]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Estádio da Luz",
                "City": "Lisbon",
                "Country": "Portugal"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-9.1847, 38.7528]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Estadio Santiago Bernabéu",
                "City": "Madrid",
                "Country": "Spain"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-3.6883, 40.4531]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Groupama Stadium",
                "City": "Lyon",
                "Country": "France"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [4.9810, 45.7657]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "BT Murrayfield Stadium",
                "City": "Edinburgh",
                "Country": "United Kingdom"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-3.2408, 55.9426]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Anfield",
                "City": "Liverpool",
                "Country": "United Kingdom"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-2.9608, 53.4308]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Principality Stadium",
                "City": "Cardiff",
                "Country": "United Kingdom"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-3.1821, 51.4782]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Wembley Stadium",
                "City": "London",
                "Country": "United Kingdom"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-0.2796, 51.5560]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Croke Park",
                "City": "Dublin",
                "Country": "Ireland"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-6.2518, 53.3607]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Johan Cruyff Arena",
                "City": "Amsterdam",
                "Country": "Netherlands"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [4.9413, 52.3141]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Letzigrund Stadium",
                "City": "Zurich",
                "Country": "Switzerland"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [8.5044, 47.3826]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "San Siro",
                "City": "Milan",
                "Country": "Italy"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [9.1232, 45.4781]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Veltins-Arena",
                "City": "Gelsenkirchen",
                "Country": "Germany"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [7.0676, 51.5548]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Volksparkstadion",
                "City": "Hamburg",
                "Country": "Germany"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [9.8986, 53.5879]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Allianz Arena",
                "City": "Munich",
                "Country": "Germany"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [11.6247, 48.2188]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "National Stadium",
                "City": "Warsaw",
                "Country": "Poland"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [21.0456, 52.2395]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Ernst-Happel-Stadion",
                "City": "Vienna",
                "Country": "Austria"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [16.4202, 48.2014]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "Rogers Centre",
                "City": "Toronto",
                "Country": "Canada"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-79.3893, 43.6415]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "Stadium": "BC Place",
                "City": "Vancouver",
                "Country": "Canada"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [-123.1113, 49.2768]
            }
        }
    ]
}

# Save the GeoJSON data to a file
geojson_file = "taylor_eras_tour_stadiums.geojson"
with open(geojson_file, 'w') as f:
    json.dump(geojson, f)
